# %% [markdown]
# ![](figs/foro_programacion_vida_digital_banner.jpg "2do Foro Interncacional de Programación y Vida Digital Banner")

# %% [markdown]
# ## 2do Foro Interncacional de Programación y Vida Digital
# ### Taller: Introducción al Análisis de Datos con Python
# #### Emmanuel Romero
# #### em.romero@uabcs.mx

# %%
######################################
# Obtención del conjunto de datos
# Iris: https://archive.ics.uci.edu/dataset/53/iris

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("https://raw.githubusercontent.com/romeroqe/supplementary/main/workshops/data/iris.csv", skiprows=3)
df.head(52)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width          species
# 0            5.1          3.5           1.4          0.2      Iris-setosa
# 1            4.9          3.0           1.4          0.2      Iris-setosa
# 2            4.7          3.2           1.3          0.2      Iris-setosa
# 3            4.6          3.1           1.5          0.2      Iris-setosa
# 4            5.0          3.6           1.4          0.2      Iris-setosa
# 5            5.4          3.9           1.7          0.4      Iris-setosa
# 6            4.6          3.4           1.4          0.3      Iris-setosa
# 7            5.0          3.4           1.5          0.2      Iris-setosa
# 8            4.4          2.9           1.4          0.2      Iris-setosa
# 9            4.9          3.1           1.5          0.1      Iris-setosa
# 10           5.4          3.7           1.5          0.2      Iris-setosa
# 11           4.8          3.4           1.6          0.2      Iris-setosa
# ...

# %%
df.shape
# Out:
# (150, 5)

# %%
######################################
# Exploración inicial

print('Tamaño del dataset:')
df.shape # (Cuantas muestras, cuantas características)
# Out:
# Tamaño del dataset:
# (150, 5)

# %%
print('Resumen del dataset:')
df.info()
# Out:
# Resumen del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
print('Descripción del dataset:')
df.describe()
# Out:
# Descripción del dataset:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print('Conteo de valores nulos:')
df.isnull().sum(axis=0) # Cuantos valores faltantes hay?
# df.dropna()
# Out:
# Conteo de valores nulos:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
######################################
# Exploración por especie

print('Distribución de las especies:')
df['species'].value_counts() # Cuantas muestras hay por especie?
# Out:
# Distribución de las especies:
# species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
df_setosa = df[df.species == "Iris-setosa"].reset_index(drop=True)
df_setosa.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
df_versicolor = df[df.species == "Iris-versicolor"].reset_index(drop=True)
df_versicolor.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0           7.0          3.2           4.7          1.4  Iris-versicolor
# 1           6.4          3.2           4.5          1.5  Iris-versicolor
# 2           6.9          3.1           4.9          1.5  Iris-versicolor
# 3           5.5          2.3           4.0          1.3  Iris-versicolor
# 4           6.5          2.8           4.6          1.5  Iris-versicolor

# %%
df_virginica = df[df.species == "Iris-virginica"].reset_index(drop=True)
df_virginica.head(5)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width         species
# 0           6.3          3.3           6.0          2.5  Iris-virginica
# 1           5.8          2.7           5.1          1.9  Iris-virginica
# 2           7.1          3.0           5.9          2.1  Iris-virginica
# 3           6.3          2.9           5.6          1.8  Iris-virginica
# 4           6.5          3.0           5.8          2.2  Iris-virginica

# %%
df_setosa.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        5.00600     3.418000      1.464000      0.24400
# std         0.35249     0.381024      0.173511      0.10721
# min         4.30000     2.300000      1.000000      0.10000
# 25%         4.80000     3.125000      1.400000      0.20000
# 50%         5.00000     3.400000      1.500000      0.20000
# 75%         5.20000     3.675000      1.575000      0.30000
# max         5.80000     4.400000      1.900000      0.60000

# %%
df_virginica.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count      50.00000    50.000000     50.000000     50.00000
# mean        6.58800     2.974000      5.552000      2.02600
# std         0.63588     0.322497      0.551895      0.27465
# min         4.90000     2.200000      4.500000      1.40000
# 25%         6.22500     2.800000      5.100000      1.80000
# 50%         6.50000     3.000000      5.550000      2.00000
# 75%         6.90000     3.175000      5.875000      2.30000
# max         7.90000     3.800000      6.900000      2.50000

# %%
fig, axs = plt.subplots(ncols=4, figsize=(15, 5))
sns.boxplot(data=df, x='species', y="sepal_length", ax=axs[0], hue='species')
axs[0].set_title("sepal_length")
sns.boxplot(data=df, x='species', y="sepal_width", ax=axs[1], hue='species')
axs[1].set_title("sepal_width")
sns.boxplot(data=df, x='species', y="petal_length", ax=axs[2], hue='species')
axs[2].set_title("petal_length")
sns.boxplot(data=df, x='species', y="petal_width", ax=axs[3], hue='species')
axs[3].set_title("petal_width")
plt.tight_layout()

# %%
fig, axs = plt.subplots(ncols=4, figsize=(15, 5))
sns.violinplot(data=df, x='species', y="sepal_length", ax=axs[0], hue='species')
axs[0].set_title("sepal_length")
sns.violinplot(data=df, x='species', y="sepal_width", ax=axs[1], hue='species')
axs[1].set_title("sepal_width")
sns.violinplot(data=df, x='species', y="petal_length", ax=axs[2], hue='species')
axs[2].set_title("petal_length")
sns.violinplot(data=df, x='species', y="petal_width", ax=axs[3], hue='species')
axs[3].set_title("petal_width")
plt.tight_layout()

# %%
sns.pairplot(df, hue="species", diag_kind="hist")#, corner=True)

# %%
df[["sepal_length","sepal_width","petal_length","petal_width"]].corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
fig = plt.figure(figsize = (6,4))
sns.heatmap(df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']].corr(), cmap='coolwarm', annot=True, vmin=-1, vmax=1);

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
import numpy as np

X = df[["sepal_length","sepal_width","petal_length","petal_width"]].values
y = df[["species"]].values
print(f"Son {X.shape[0]} muestras totales")

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)
print(f"Son {X_train.shape[0]} muestras para entrenamiento y {X_test.shape[0]} datos para prueba")
# Out:
# Son 150 muestras totales
# Son 120 muestras para entrenamiento y 30 datos para prueba

# %%
y_test
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-virginica'],
#        ['Iris-virginica'],
#        ['Iris-versicolor'],
#        ['Iris-virginica'],
#        ['Iris-setosa'],
#        ['Iris-versicolor']], dtype=object)

# %%
algoritmo = KNeighborsClassifier(n_neighbors=5)
algoritmo.fit(X_train, y_train)

Y_pred = algoritmo.predict(X_test)
accuracy = algoritmo.score(X_train, y_train)
print(f"Exactitud Vecinos más Cercanos: {accuracy*100}%")
# Out:
# Exactitud Vecinos más Cercanos: 98.33333333333333%
# C:\Users\romer\anaconda3\Lib\site-packages\sklearn\neighbors\_classification.py:238: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
1000000*(1.6/100)

# %%
1000000-(1000000*(1.6/100))

# %%
# Graficando muestras de entrenamiento
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

fig, ax = plt.subplots(figsize=(6.8,4.2))
# X_train[:,-2:]
# y_train
species = np.unique(y_train)
y_train[y_train == species[0]] = 0
y_train[y_train == species[1]] = 1
y_train[y_train == species[2]] = 2
y_train = y_train.flatten()

X_train = X_train[:,-2:]

colors = ["tab:blue", "tab:orange", "tab:green"]

for k in range(len(species)):
    i_species = y_train == k
    ax.scatter(X_train[i_species,0], X_train[i_species,1], c=colors[k], label=species[k])
    
ax.set_ylabel("petal_width")
ax.set_xlabel("petal_length")
ax.legend()

# %%
# Graficando muestras de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

fig, ax = plt.subplots(figsize=(6.8,4.2))

species = np.unique(y_train)
y_train[y_train == species[0]] = 0
y_train[y_train == species[1]] = 1
y_train[y_train == species[2]] = 2
y_train = y_train.flatten()

y_test[y_test == species[0]] = 0
y_test[y_test == species[1]] = 1
y_test[y_test == species[2]] = 2
y_test = y_test.flatten()

X_train = X_train[:,-2:]

X_test = X_test[:,-2:]

colors = ["tab:blue", "tab:orange", "tab:green"]

for k in range(len(species)):
    # Entrenamiento
    i_species = y_train == k
    ax.scatter(X_train[i_species,0], X_train[i_species,1], c=colors[k], label=species[k])
    # Pruebas
    i_species = y_test == k
    ax.scatter(X_test[i_species,0], X_test[i_species,1], c=colors[k], marker="d", edgecolors="k", zorder=5)
    
ax.set_ylabel("petal_width")
ax.set_xlabel("petal_length")
ax.legend()

# %%
np.random.uniform(1.5, 5.5, size=10)
# Out:
# array([4.65421602, 3.38187002, 3.49381673, 3.58611688, 5.09337705,
#        4.47238063, 4.22191458, 1.62553825, 2.97542593, 3.00308471])

# %%
size = 10
iris = pd.DataFrame({
    "sepal_length": np.random.uniform(df["sepal_length"].min(), df["sepal_length"].max(), size=size),
    "sepal_width": np.random.uniform(df["sepal_width"].min(), df["sepal_width"].max(), size=size),
    "petal_length": np.random.uniform(df["petal_length"].min(), df["petal_length"].max(), size=size),
    "petal_width": np.random.uniform(df["petal_width"].min(), df["petal_width"].max(), size=size),
})
iris
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0      7.434037     3.545151      5.235127     2.401722
# 1      7.329037     3.755140      2.969711     0.155160
# 2      5.652810     2.151194      5.281519     2.343664
# 3      6.691263     2.677843      5.784716     0.423119
# 4      4.334863     2.171134      6.142434     1.123573
# 5      5.350540     3.014636      2.965258     1.337031
# 6      5.413444     4.157546      2.841041     1.272165
# 7      4.544777     3.539049      2.743935     0.553109
# 8      5.038383     3.868290      3.074880     1.488463
# 9      7.052025     4.332061      1.194892     0.918562

# %%
Y_pred = algoritmo.predict(iris.values)
iris["species"] = Y_pred
iris
# Out:
#    sepal_length  sepal_width  petal_length  petal_width          species
# 0      7.434037     3.545151      5.235127     2.401722   Iris-virginica
# 1      7.329037     3.755140      2.969711     0.155160  Iris-versicolor
# 2      5.652810     2.151194      5.281519     2.343664   Iris-virginica
# 3      6.691263     2.677843      5.784716     0.423119   Iris-virginica
# 4      4.334863     2.171134      6.142434     1.123573   Iris-virginica
# 5      5.350540     3.014636      2.965258     1.337031  Iris-versicolor
# 6      5.413444     4.157546      2.841041     1.272165      Iris-setosa
# 7      4.544777     3.539049      2.743935     0.553109      Iris-setosa
# 8      5.038383     3.868290      3.074880     1.488463  Iris-versicolor
# 9      7.052025     4.332061      1.194892     0.918562      Iris-setosa

# %%
# Graficando muestras de entrenamiento, prueba y nuevas muestras
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=30)

fig, ax = plt.subplots(figsize=(6.8,4.2))

species = np.unique(y_train)
y_train[y_train == species[0]] = 0
y_train[y_train == species[1]] = 1
y_train[y_train == species[2]] = 2
y_train = y_train.flatten()

y_test[y_test == species[0]] = 0
y_test[y_test == species[1]] = 1
y_test[y_test == species[2]] = 2
y_test = y_test.flatten()

y_pred = iris["species"].values
y_pred[y_pred == species[0]] = 0
y_pred[y_pred == species[1]] = 1
y_pred[y_pred == species[2]] = 2
y_pred = y_pred.flatten()

X_train = X_train[:,-2:]

X_test = X_test[:,-2:]

X_pred = iris[["petal_length","petal_width"]].values

colors = ["tab:blue", "tab:orange", "tab:green"]

for k in range(len(species)):
    # Entrenamiento
    i_species = y_train == k
    ax.scatter(X_train[i_species,0], X_train[i_species,1], c=colors[k], label=species[k])
    # Pruebas
    i_species = y_test == k
    ax.scatter(X_test[i_species,0], X_test[i_species,1], c=colors[k], zorder=5)
    # Nuevas muestras
    i_species = y_pred == k
    ax.scatter(X_pred[i_species,0], X_pred[i_species,1], c=colors[k], marker="s", zorder=10, edgecolors="k")
    
ax.set_ylabel("petal_width")
ax.set_xlabel("petal_length")
ax.legend().set_zorder(50)
